# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 20]

# %%
import radio as rio
from radio.data import get_first_batch

# %% [markdown]
# ### Medical Segmentation Decathlon - Task 04: Hippocampus

# %% [markdown]
# #### Setup Data

# %%
data = rio.data.MedicalDecathlonDataModule(use_augmentation=True)
data.prepare_data()
data.setup()
print(f"Training: {data.size_train} subjects.")
print(f"Validation: {data.size_val} subjects.")
print(f"Test: {data.size_test} subjects.")
# Out:
# Training: 208 subjects.
# Validation: 52 subjects.
# Test: 130 subjects.

# %% [markdown]
# #### Get a Train and a Test Batch

# %%
train_dataloaders = data.train_dataloader()
val_dataloaders = data.val_dataloader()
test_dataloaders = data.test_dataloader()

# %%
train_batch = get_first_batch(train_dataloaders[0])
test_batch = get_first_batch(test_dataloaders[0])

# %% [markdown]
# #### Plot Example Samples from Batches

# %%
rio.data.plot_train_batch(train_batch)
# Out:
# image shape: torch.Size([48, 64, 48]), label shape: torch.Size([48, 64, 48])

# %%
rio.data.plot_test_batch(test_batch)
# Out:
# image shape: torch.Size([48, 64, 48])
